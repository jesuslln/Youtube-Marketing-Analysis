# %%
#Imports

from pymongo import MongoClient

import pandas as pd
import numpy as np

# %%
# Connect to the MongoDB cluster
client = MongoClient('mongodb+srv://201910180:eMGUcz63Ykle2InB@clusterdav.cjkz7i5.mongodb.net/?retryWrites=true&w=majority')

# Select the database
database = client['Youtube_Netflix']

# # Access a specific collection within that database
collection_comments = database['Comments']



num_comments = collection_comments.count_documents({'_id' : {'$exists' : 1}})
print ( 'Number of documents in database = ' + str(num_comments) )



cursor = collection_comments.find().skip(5000).limit(3)

for doc in cursor:
    print("Comment Id is: " + doc['id'])
    print("Video Id is: " + doc['snippet']['videoId'])
    print("Author Channel Id is: " + doc['snippet']['topLevelComment']['snippet']['authorChannelId']['value'])
    print("Comment Text is: " + doc['snippet']['topLevelComment']['snippet']['textDisplay'])
    print("Date Published is : " + doc['snippet']['topLevelComment']['snippet']['publishedAt'])
    print("Comment likes : " + str(doc['snippet']['topLevelComment']['snippet']['likeCount']))
    print("Comment Replies: " + str(doc['snippet']['totalReplyCount']))
# Out:
# Number of documents in database = 38145
# Comment Id is: UgyuehmVqSUagrKRdER4AaABAg
# Video Id is: 0hgZPvMU7So
# Author Channel Id is: UCdJAYXEbiKQkrkOGcw9wBJQ
# Comment Text is: &quot;What if your data was stored in a house plant?&quot;<br><br>Please no.
# Date Published is : 2022-06-13T17:23:55Z
# Comment likes : 22
# Comment Replies: 2
# Comment Id is: UgwxvHt9TfMo0A5gYit4AaABAg
# Video Id is: JF_QYFb8vc4
# Author Channel Id is: UCjLgaAdqiWPqibCgORtbz0w
# Comment Text is: Jeff looked like he didn’t want to be there when that too hot to handle game  showed up
# Date Published is : 2022-06-11T03:36:02Z
# Comment likes : 1
# Comment Replies: 0
# Comment Id is: UgyrWyxNS5tMzDv0YhF4AaABAg
# Video Id is: JF_QYFb8vc4
# Author Channel Id is: UCHd96oscFdvOyds-BRPa_XQ
# ...

# %%
from pandas.io.json import json_normalize

# Get comments of all videos
comments = []
comment = {}

cursor = collection_comments.find()

# AÑADIR API KEY

for doc in cursor:
  comment["Comment_id"] = doc['id']
  comment["Video_id"] = doc['snippet']['videoId']
  comment["Channel_id"] = doc['snippet']['topLevelComment']['snippet']['authorChannelId']['value']
  comment["Text"] = doc['snippet']['topLevelComment']['snippet']['textDisplay']
  comment["Date"] = doc['snippet']['topLevelComment']['snippet']['publishedAt']
  comment["Comment_likes"] = doc['snippet']['topLevelComment']['snippet']['likeCount']
  comment["Replies"] = doc['snippet']['totalReplyCount']
  comments.append(comment.copy())



# print("Comment Id is: " + doc['id'])
#     print("Video Id is: " + doc['snippet']['videoId'])
#     print("Author Channel Id is: " + doc['snippet']['topLevelComment']['snippet']['authorChannelId']['value'])
#     print("Comment Text is: " + doc['snippet']['topLevelComment']['snippet']['textDisplay'])
#     print("Date Published is : " + doc['snippet']['topLevelComment']['snippet']['publishedAt'])
#     print("Comment likes : " + str(doc['snippet']['topLevelComment']['snippet']['likeCount']))
#     print("Comment Replies: " + str(doc['snippet']['totalReplyCount']))


# for v in all_videos:
#   video_url = url + "&videoId="+v["videoId"]
#   payload = {}
#   headers = {}
#   response = requests.request("GET", video_url, headers=headers, data=payload)
#   if response.status_code == 200:
#     response_content = response.json()
#     print(response_content)
#     for resp in response_content["items"]:
#       print(resp)
#       comment["videoId"] = resp['snippet']["videoId"]
#       comment["textDisplay"] = resp["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
#       comment["likeCount"] = resp["snippet"]["topLevelComment"]["snippet"]["likeCount"]
#       comment["publishedAt"] = resp["snippet"]["topLevelComment"]["snippet"]["publishedAt"]
#       comment["totalReplyCount"] = resp["snippet"]["totalReplyCount"]
    
#       comments.append(comment.copy())


#   else:
#     print("ERROR")

# %%
len(comments)
print(comments[5])
print(comments[5000])
# Out:
# {'Comment_id': 'UgzlVBgJHWz6cHPUyHF4AaABAg', 'Video_id': 'L59S_Adzunw', 'Channel_id': 'UCUHOXhIDhbhi5wo0L9cAB8w', 'Text': '😄', 'Date': '2024-03-03T20:19:44Z', 'Comment_likes': 1, 'Replies': 0}
# {'Comment_id': 'UgyuehmVqSUagrKRdER4AaABAg', 'Video_id': '0hgZPvMU7So', 'Channel_id': 'UCdJAYXEbiKQkrkOGcw9wBJQ', 'Text': '&quot;What if your data was stored in a house plant?&quot;<br><br>Please no.', 'Date': '2022-06-13T17:23:55Z', 'Comment_likes': 22, 'Replies': 2}

# %%
collection_video = database['Videos']
videos_col = collection_video.find()

videos = []
count=0
for v in videos_col:
    videos.append(v.copy())

# %%
count=0
for v in videos:
    if(count < 2):
        print(v)

    count += 1
# Out:
# {'_id': ObjectId('65e5af76704102a87caf53a5'), 'videoId': 'L59S_Adzunw', 'publishedAt': '2024-03-03T20:00:00Z', 'title': 'this scene is electric #code8partII', 'description': 'Code 8 Part II is now playing #shorts #netflix Watch on Netflix: https://www.netflix.com/title/81480320 About Netflix: Netflix is one of ...', 'viewCount': '17880', 'likeCount': '1057', 'favoriteCount': '0', 'commentCount': '17'}
# {'_id': ObjectId('65e5af76704102a87caf53a6'), 'videoId': 'VrjHt3MT9BY', 'publishedAt': '2024-03-01T20:00:00Z', 'title': 'Mea Culpa&#39;s Trevante Rhodes is looking at you.', 'description': 'Pssst Trevante Rhodes is trying to flirt with you #MeaCulpa #netflix Watch on Netflix: https://www.netflix.com/title/81577005 About ...', 'viewCount': '21246', 'likeCount': '942', 'favoriteCount': '0', 'commentCount': '32'}

# %%
videos[50]
# Out:
# {'_id': ObjectId('65e5af76704102a87caf547c'),
#  'videoId': 'Dn5UhUMCSz0',
#  'publishedAt': '2021-09-08T13:00:00Z',
#  'title': 'Baking Impossible Season 1 | Official Trailer | Netflix',
#  'description': 'Top-tier bakers and engineers team up on missions to build delectable, incredible designs for a $100000 prize and the title of ...',
#  'viewCount': '191201',
#  'likeCount': '2454',
#  'favoriteCount': '0',
#  'commentCount': '507'}

# %%
# Connect to MongoDB
db = client["Netflix_Youtube"]  # AÑADIR NOMBRE DE BD
# collection_videos = db["Videos"]  # AÑADIR NOMBRES DE COLECCIONES
collection_comments = db["Comments"]

# Insert data into collection

# Videos DB
# collection_videos.insert_many(videos)

# Comments DB

collection_comments.insert_many(comments)
# Out:
# InsertManyResult([ObjectId('65e9a63583692cddeaba7fa0'), ObjectId('65e9a63583692cddeaba7fa1'), ObjectId('65e9a63583692cddeaba7fa2'), ObjectId('65e9a63583692cddeaba7fa3'), ObjectId('65e9a63583692cddeaba7fa4'), ObjectId('65e9a63583692cddeaba7fa5'), ObjectId('65e9a63583692cddeaba7fa6'), ObjectId('65e9a63583692cddeaba7fa7'), ObjectId('65e9a63583692cddeaba7fa8'), ObjectId('65e9a63583692cddeaba7fa9'), ObjectId('65e9a63583692cddeaba7faa'), ObjectId('65e9a63583692cddeaba7fab'), ObjectId('65e9a63583692cddeaba7fac'), ObjectId('65e9a63583692cddeaba7fad'), ObjectId('65e9a63583692cddeaba7fae'), ObjectId('65e9a63583692cddeaba7faf'), ObjectId('65e9a63583692cddeaba7fb0'), ObjectId('65e9a63583692cddeaba7fb1'), ObjectId('65e9a63583692cddeaba7fb2'), ObjectId('65e9a63583692cddeaba7fb3'), ObjectId('65e9a63583692cddeaba7fb4'), ObjectId('65e9a63583692cddeaba7fb5'), ObjectId('65e9a63583692cddeaba7fb6'), ObjectId('65e9a63583692cddeaba7fb7'), ObjectId('65e9a63583692cddeaba7fb8'), ObjectId('65e9a63583692cddeaba
# ...
